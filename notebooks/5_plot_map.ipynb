# %% [markdown]
# Import libraries

# %%
import sys
sys.path.append("../src")
from visualization import map_plotter
import pandas as pd
import json

# %% [markdown]
# Get the Mercyhurst University coordinates and load the data

# %%
with open("../data/raw/mercyhurst_coordinates.txt") as file:
    ll = json.loads(file.read())['ll']
    file.close()
location = eval(ll)
df_venues = pd.read_csv('../data/processed/venues_with_clusters.csv')
df_venues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        47 non-null     float64
#  1   longitude       47 non-null     float64
#  2   fsq_id          47 non-null     object
#  3   address         47 non-null     object
#  4   country         47 non-null     object
#  5   postal_code     47 non-null     object
#  6   region          47 non-null     object
#  7   restaurants     47 non-null     int64
#  8   groceries       47 non-null     int64
#  9   cluster         47 non-null     int64
#  10  recomended for  47 non-null     object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 4.2+ KB

# %%
mp=map_plotter.MapPlotter(location)
mp.plot_map(df_venues[['latitude','longitude']], df_venues['cluster'],df_venues[['recomended for','restaurants','groceries','region']])
mp.save_map()
mp.map
# Out:
# c:\Users\HP\OneDrive\Desktop\Projects\student-accommodation-clustering\notebooks\../src\visualization\map_plotter.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lat=df_loc.iloc[ind][0]
# c:\Users\HP\OneDrive\Desktop\Projects\student-accommodation-clustering\notebooks\../src\visualization\map_plotter.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   long=df_loc.iloc[ind][1]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# ...
